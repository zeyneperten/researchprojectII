# %%
import os
import sys
import socket
import platform
import numpy as np
import neo

# 1. Identity Check
print(f"🚀 System Name: {socket.gethostname()}")
print(f"📂 Working Directory: {os.getcwd()}")

# 2. Path Check (This confirms if you are in the Poetry venv)
print(f"🐍 Python Executable: {sys.executable}")

# 3. Hardware Check (RAM)
# This looks at the Linux system memory
total_memory = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES') / (1024**3)
print(f"🐘 Available RAM on Server: {total_memory:.2f} GB")

# 4. Library Check
print(f"📊 Numpy Version: {np.__version__}")
print(f"🧠 Neo Version: {neo.__version__}")
# Out:
# 🚀 System Name: hawaii
# 📂 Working Directory: /home/thinkstation/zeynep/researchprojectII
# 🐍 Python Executable: /home/thinkstation/zeynep/researchprojectII/.venv/bin/python
# 🐘 Available RAM on Server: 30.96 GB
# 📊 Numpy Version: 2.3.5
# 🧠 Neo Version: 0.14.4
